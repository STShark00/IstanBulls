# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as sm

# %%
player_stats_2223 = pd.read_csv("NBA Stats 202223 All Stats  NBA Player Props Tool.csv")
player_stats_2223 = player_stats_2223.set_index("RANK")
player_stats_2223["Year"] = 2023
player_stats_2223
# Out:
#                    NAME TEAM  POS   AGE  GP   MPG  USG%   TO%  FTA    FT%  \
# RANK
# 1       Dejounte Murray  Atl    G  26.4  56  36.4  24.8  11.1  135  0.837
# 2            Trae Young  Atl    G  24.4  54  35.3  33.2  17.2  478  0.889
# 3       De'Andre Hunter  Atl  F-G  25.2  51  31.7  19.8   9.1  176  0.830
# 4          John Collins  Atl  F-C  25.4  51  31.0  17.0  10.6  128  0.813
# 5     Bogdan Bogdanovic  Atl    G  30.5  36  29.6  20.2   9.2   50  0.780
# ...                 ...  ...  ...   ...  ..   ...   ...   ...  ...    ...
# 564        Johnny Davis  Was    G  21.0  13   4.7  15.1   9.8    3  1.000
# 565         Isaiah Todd  Was    F  21.4   4   3.2  13.8   0.0    0  0.000
# 566      Jordan Schakel  Was    G  24.7   2   3.1  14.0   0.0    0  0.000
# 567    Vernon Carey Jr.  Was  F-C  22.0  11   2.6  16.6  19.2    2  1.000
# 568     Quenton Jackson  Was    G  24.5   3   2.6  16.7   0.0    0  0.000
#
#       ...  SPG  BPG  TPG   P+R   P+A  P+R+A   VI  ORtg   DRtg  Year
# ...

# %%
player_stats_2122 = pd.read_excel("NBA Stats 202122 All Player Statistics in one Page.xlsx")
player_stats_2122 = player_stats_2122.set_index("RANK")
player_stats_2122["Year"] = 2022
player_stats_2122
# Out:
#               FULL NAME TEAM  POS    AGE  GP   MPG  MIN%  USG%   TO%  FTA  \
# RANK
# 1      Precious Achiuwa  Tor    F  22.56  73  23.6  49.2  18.5  11.3  131
# 2          Steven Adams  Mem    C  28.73  76  26.3  54.8  12.0  19.6  199
# 3           Bam Adebayo  Mia  C-F  24.73  56  32.6  67.9  25.0  14.4  340
# 4          Santi Aldama  Mem  F-C  21.25  32  11.2  23.4  18.5   9.9   32
# 5     LaMarcus Aldridge  Bro  C-F  36.73  47  22.3  46.5  22.4   8.0  102
# ...                 ...  ...  ...    ...  ..   ...   ...   ...   ...  ...
# 712      Thaddeus Young  Tor    F  33.80  26  18.3  38.1  16.0  12.4   27
# 713          Trae Young  Atl    G  23.56  76  34.9  72.7  34.4  14.5  553
# 714      Omer Yurtseven  Mia    C  23.81  56  12.6  26.3  19.8  13.0   61
# 715         Cody Zeller  Por  F-C  29.51  27  13.1  27.4  16.0  14.6   49
# 716         Ivica Zubac  Lac    C  25.07  76  24.4  50.8  16.8  16.0  227
#
#       ...  TRB%  APG  AST%   SPG   BPG  TOPG    VI   ORTG   DRTG  Year
# ...

# %%
player_stats_2021 = pd.read_excel("2020-2021 NBA Stats  Player Box Score  Advanced Metrics.xlsx")
player_stats_2021 = player_stats_2021.set_index("RANK")
player_stats_2021["Year"] = 2021
player_stats_2021
# Out:
#               FULL NAME TEAM  POS    AGE  GP   MPG  MIN%  USG%   TO%  FTA  \
# RANK
# 1      Precious Achiuwa  Mia    F  21.66  61  12.1  25.2  19.5  13.5  110
# 2          Jaylen Adams  Mil    G  25.03   7   2.6   5.4  18.5   0.0    0
# 3          Steven Adams  Nor    C  27.83  58  27.7  57.6  11.7  17.7  135
# 4           Bam Adebayo  Mia  C-F  23.83  64  33.5  69.7  23.7  15.0  354
# 5     LaMarcus Aldridge  San  C-F  35.83  21  25.9  54.0  22.7   7.0   37
# ...                 ...  ...  ...    ...  ..   ...   ...   ...   ...  ...
# 622        Delon Wright  Sac    G  29.06  27  25.8  53.7  17.1  12.7   36
# 623      Thaddeus Young  Chi    F  32.90  68  24.3  50.6  22.3  16.0  113
# 624          Trae Young  Atl    G  22.66  63  33.7  70.3  33.0  16.2  546
# 625         Cody Zeller  Cha  F-C  28.61  48  20.9  43.6  18.3  11.9  119
# 626         Ivica Zubac  Lac    C  24.16  72  22.3  46.5  15.2  14.7  171
#
#       ...  TRB%  APG  AST%   SPG   BPG  TOPG    VI   ORTG   DRTG  Year
# ...

# %%
player_stats_1920 = pd.read_excel("2019-2020 NBA Player Stats.xlsx")
player_stats_1920 = player_stats_1920.set_index("RANK")
player_stats_1920["Year"] = 2020
player_stats_1920
# Out:
#                      FULL NAME TEAM  POS    AGE  GP   MPG  MIN%  USG%   TO%  \
# RANK
# 1                 Steven Adams  Okc    C  27.07  63  26.7  55.6  17.3  14.4
# 2                  Bam Adebayo  Mia  C-F  23.08  72  33.6  69.9  21.2  17.5
# 3            LaMarcus Aldridge  San  F-C  35.07  53  33.1  68.9  23.4   7.8
# 4               Kyle Alexander  Mia  F-C  23.81   2   6.7  14.0   9.9  33.3
# 5     Nickeil Alexander-Walker  Nor    G  21.95  47  12.6  26.2  23.3  16.1
# ...                        ...  ...  ...    ...  ..   ...   ...   ...   ...
# 587                 Trae Young  Atl    G  21.90  60  35.3  73.6  34.9  16.2
# 588                Cody Zeller  Cha    C  27.86  58  23.1  48.2  20.8  11.8
# 589               Tyler Zeller  San  F-C  30.58   2   2.0   4.1  44.3   0.0
# 590                 Ante Zizic  Cle    C  23.61  22  10.0  20.9  17.5  11.1
# 591                Ivica Zubac  Lac    C  23.41  72  18.4  38.4  16.4  11.7
#
# ...

# %%
player_stats_1819 = pd.read_excel("2018-2019 NBA Player Stats.xlsx")
player_stats_1819 = player_stats_1819.set_index("RANK")
player_stats_1819["Year"] = 2019
player_stats_1819
# Out:
#          FULL NAME TEAM  POS    AGE  GP   MPG  MIN%  USG%  Tor%  FTA  ...  \
# RANK                                                                  ...
# 1     Alex Abrines  Okc    G  25.69  31  19.0  39.5  12.2   7.9   13  ...
# 2       Quincy Acy  Pho    F  28.51  10  12.3  25.6   9.2  15.2   10  ...
# 3     Jaylen Adams  Atl    G  22.93  34  12.6  26.2  13.5  19.7    9  ...
# 4     Steven Adams  Okc    C  25.73  80  33.4  69.5  16.4  12.8  292  ...
# 5      Bam Adebayo  Mia  C-F  21.73  82  23.3  48.6  15.8  17.1  226  ...
# ...            ...  ...  ...    ...  ..   ...   ...   ...   ...  ...  ...
# 618   Tyler Zeller  Atl    C  29.23   2   5.4  11.1   7.6   0.0    0  ...
# 619   Tyler Zeller  Mem    C  29.23   4  20.6  42.8  21.7  10.0   18  ...
# 620     Ante Zizic  Cle    C  22.27  59  18.3  38.2  18.2  13.8  132  ...
# 621    Ivica Zubac  Lal    C  22.07  33  15.6  32.6  20.5  12.9   66  ...
# 622    Ivica Zubac  Lac    C  22.07  26  20.1  41.9  20.1  14.8   60  ...
#
# ...

# %%
player_stats_1718 = pd.read_html("https://www.nbastuffer.com/2017-2018-nba-player-stats/")[1]
player_stats_1718 = player_stats_1718.set_index("RANK")
player_stats_1718["Year"] = 2018
player_stats_1718.columns = player_stats_1819.columns
player_stats_1718
# Out:
#            FULL NAME TEAM POS   AGE  GP   MPG  MIN%  USG%   Tor%  FTA  ...  \
# RANK                                                                   ...
# NaN     Aaron Brooks  Min  PG  33.0  32   5.9  12.3  19.8  0.130   11  ...
# NaN     Aaron Gordon  Orl  SF  22.0  58  32.9  68.6  24.7  0.100  225  ...
# NaN   Aaron Harrison  Dal  SG  23.0   9  25.9  54.0  15.5  0.038   17  ...
# NaN    Aaron Jackson  Hou   F  31.0   1  34.5  71.9  13.9  0.092    2  ...
# NaN      Abdel Nader  Bos  SF  24.0  48  10.9  22.6  17.1  0.170   39  ...
# ...              ...  ...  ..   ...  ..   ...   ...   ...    ...  ...  ...
# NaN     Zach Collins  Por   C  20.0  66  15.8  33.0  15.4  0.161   42  ...
# NaN      Zach LaVine  Chi  SG  22.0  24  27.3  57.0  29.5  0.097  107  ...
# NaN    Zach Randolph  Sac  PF  36.0  59  25.6  53.2  27.6  0.125  107  ...
# NaN    Zaza Pachulia  Gol   C  33.0  69  14.1  29.3  17.0  0.194   93  ...
# ...

# %%
player_stats_1617 = pd.read_html("https://www.nbastuffer.com/2016-2017-nba-regular-season-player-stats/")[0]
#player_stats_1617 = player_stats_1718.set_index("RANK")

#player_stats_1617.columns = player_stats_1819.columns


player_stats_1617.columns = player_stats_1617.columns.droplevel()
player_stats_1617["Year"] = 2017

player_stats_1617.drop(columns=['Unnamed: 25_level_1'], inplace=True)
player_stats_1617
# Out:
#      Rank         PLAYER TEAM POS  AGE  GP   MPG  MIN%  USG%    TOr  ...  \
# 0     NaN   Aaron Brooks  Ind  PG   32  65  13.7  28.6  19.2  0.170  ...
# 1     NaN   Aaron Gordon  Orl  SF   21  80  28.7  59.8  20.1  0.085  ...
# 2     NaN  Adreian Payne  Min  PF   25  18   7.5  15.7  23.0  0.114  ...
# 3     NaN     AJ Hammons  Dal   C   24  22   7.4  15.5  17.6  0.164  ...
# 4     NaN     Al Horford  Bos   C   30  68  32.3  67.2  19.7  0.118  ...
# ..    ...            ...  ...  ..  ...  ..   ...   ...   ...    ...  ...
# 500   NaN   Yogi Ferrell  Dal  PG   23  36  29.1  60.5  19.5  0.129  ...
# 501   NaN    Zach LaVine  Min  SG   21  47  37.2  77.5  21.7  0.099  ...
# 502   NaN  Zach Randolph  Mem  PF   35  73  24.5  51.0  29.2  0.086  ...
# 503   NaN  Zaza Pachulia  Gol   C   32  70  18.1  37.7  15.3  0.194  ...
# 504   NaN   Axel Toupane  Nor  SF   24   2  20.7  43.1   8.6  0.000  ...
#
#        TS%   PPG  RPG  TRB%  APG  AST%   SPG   BPG   VI  Year
# ...

# %%
player_stats_1516 = pd.read_html("https://www.nbastuffer.com/2015-2016-nba-regular-season-player-stats/")[0]

player_stats_1516.columns = player_stats_1516.columns.droplevel()
player_stats_1516["Year"] = 2016

player_stats_1516.drop(columns=['Unnamed: 25_level_1'], inplace=True)
player_stats_1516
# Out:
#      Rank          PLAYER TEAM POS  AGE  GP   MPG  MIN%  USG%    TOr  ...  \
# 0     NaN    Aaron Brooks  Chi  PG   31  69  16.1  33.4  23.0  0.141  ...
# 1     NaN    Aaron Gordon  Orl  PF   20  78  23.9  49.8  17.3  0.090  ...
# 2     NaN   Adreian Payne  Min  PF   24  52   9.3  19.5  17.9  0.186  ...
# 3     NaN      Al Horford  Atl   C   29  82  32.1  66.9  20.6  0.088  ...
# 4     NaN    Al Jefferson  Cha   C   31  47  23.3  48.6  24.2  0.058  ...
# ..    ...             ...  ...  ..  ...  ..   ...   ...   ...    ...  ...
# 492   NaN     Willie Reed  Bro  PF   25  39  10.9  22.7  18.1  0.092  ...
# 493   NaN  Xavier Munford  Mem  SG   23  14  17.5  36.4  18.0  0.153  ...
# 494   NaN     Zach LaVine  Min  PG   20  82  28.0  58.3  23.5  0.129  ...
# 495   NaN   Zach Randolph  Mem  PF   34  68  29.7  61.8  24.6  0.095  ...
# 496   NaN   Zaza Pachulia  Dal   C   31  76  26.4  54.9  16.2  0.168  ...
#
#        TS%   PPG  RPG  TRB%  APG  AST%   SPG   BPG   VI  Year
# ...

# %%
player_stats_1415 = pd.read_html("https://www.nbastuffer.com/2014-2015-nba-regular-season-player-stats/")[0]

player_stats_1415.columns = player_stats_1415.columns.droplevel()
player_stats_1415["Year"] = 2015

player_stats_1415.drop(columns=['Unnamed: 25_level_1'], inplace=True)
player_stats_1415
# Out:
#      Rank         PLAYER TEAM POS  AGE  GP   MPG  MIN%  USG%    TOr  ...  \
# 0     NaN     A.J. Price  Cle  PG   28  11   7.9  16.4  21.0  0.076  ...
# 1     NaN     A.J. Price  Ind  PG   28  10  19.3  40.2  25.4  0.094  ...
# 2     NaN     A.J. Price  Pho  PG   28   5   8.8  18.2  15.3  0.067  ...
# 3     NaN   Aaron Brooks  Chi  PG   30  82  23.0  47.9  25.4  0.149  ...
# 4     NaN   Aaron Gordon  Orl  PF   19  47  17.0  35.3  15.8  0.139  ...
# ..    ...            ...  ...  ..  ...  ..   ...   ...   ...    ...  ...
# 541   NaN   Xavier Henry  Lal  SF   23   9   9.5  19.8  14.0  0.113  ...
# 542   NaN    Zach LaVine  Min  PG   19  77  24.7  51.5  22.3  0.204  ...
# 543   NaN  Zach Randolph  Mem  PF   33  71  32.4  67.6  24.7  0.129  ...
# 544   NaN  Zaza Pachulia  Mil   C   30  73  23.7  49.4  19.4  0.182  ...
# 545   NaN   Zoran Dragic  Mia  SG   25  10   6.2  12.9  21.6  0.179  ...
#
#        TS%   PPG   RPG  TRB%  APG  AST%   SPG   BPG   VI  Year
# ...

# %%
player_stats_1314 = pd.read_html("https://www.nbastuffer.com/2013-2014-nba-regular-season-player-stats/")[0]

player_stats_1314.columns = player_stats_1314.columns.droplevel()
player_stats_1314["Year"] = 2014

player_stats_1314.drop(columns=['Unnamed: 25_level_1'], inplace=True)
player_stats_1314
# Out:
#      Rank          PLAYER TEAM POS  AGE  GP   MPG  MIN%  USG%    TOr  ...  \
# 0     NaN      Quincy Acy  Tor  SF   23   7   8.5  15.3  14.9  0.102  ...
# 1     NaN      Quincy Acy  Sac  SF   23  56  13.9  28.6   9.9  0.160  ...
# 2     NaN    Steven Adams  Okc   C   20  81  14.6  30.2  11.8  0.225  ...
# 3     NaN     Jeff Adrien  Cha  PF   27  25  10.1  20.3  10.8  0.136  ...
# 4     NaN     Jeff Adrien  Mil  PF   27  28  25.0  50.6  19.9  0.101  ...
# ..    ...             ...  ...  ..  ...  ..   ...   ...   ...    ...  ...
# 509   NaN     Tony Wroten  Phi  SG   20  72  24.3  50.2  27.9  0.177  ...
# 510   NaN      Nick Young  Lal  SG   28  64  28.1  58.3  27.0  0.086  ...
# 511   NaN  Thaddeus Young  Phi  PF   25  79  34.2  70.6  24.3  0.107  ...
# 512   NaN     Cody Zeller  Cha   C   21  82  17.1  35.2  19.1  0.150  ...
# 513   NaN    Tyler Zeller  Cle   C   24  70  14.8  30.3  17.4  0.149  ...
#
#        TS%   PPG  RPG  TRB%  APG  AST%   SPG   BPG   VI  Year
# ...

# %%
player_stats_1213 = pd.read_html("https://www.nbastuffer.com/2012-2013-nba-regular-season-player-stats/")[0]

player_stats_1213.columns = player_stats_1213.columns.droplevel()
player_stats_1213["Year"] = 2013

player_stats_1213.drop(columns=['Unnamed: 25_level_1'], inplace=True)
player_stats_1213
# Out:
#      Rank           PLAYER TEAM POS  AGE  GP   MPG  MIN%  USG%    TOr  ...  \
# 0     NaN       A.J. Price  Was  PG   26  57  22.2  45.7  18.2  0.127  ...
# 1     NaN     Aaron Brooks  Sac  PG   28  46  20.7  42.5  18.2  0.162  ...
# 2     NaN       Aaron Gray  Tor   C   28  42  12.0  24.3  13.4  0.248  ...
# 3     NaN       Al Horford  Atl   C   26  74  37.0  76.4  21.9  0.113  ...
# 4     NaN     Al Jefferson  Uta   C   28  78  32.5  67.1  25.7  0.073  ...
# ..    ...              ...  ...  ..  ...  ..   ...   ...   ...    ...  ...
# 419   NaN     Willie Green  Lac  SG   31  72  16.3  33.9  16.8  0.072  ...
# 420   NaN  Wilson Chandler  Den  SF   25  43  24.9  50.8  22.8  0.106  ...
# 421   NaN     Xavier Henry  Nor  SG   21  50  12.3  25.4  17.6  0.133  ...
# 422   NaN    Zach Randolph  Mem  PF   31  76  34.1  70.6  23.2  0.115  ...
# 423   NaN    Zaza Pachulia  Atl   C   28  52  21.6  44.4  14.7  0.196  ...
#
#        TS%   PPG   RPG  TRB%  APG  AST%   SPG   BPG   VI  Year
# ...

# %%
player_stats_1112 = pd.read_html("https://www.nbastuffer.com/2011-2012-nba-regular-season-player-stats/")[0]

player_stats_1112.columns = player_stats_1112.columns.droplevel()
player_stats_1112["Year"] = 2012

player_stats_1112.drop(columns=['Unnamed: 25_level_1'], inplace=True)
player_stats_1112
# Out:
#      Rank         PLAYER TEAM POS  AGE  GP   MPG  MIN%  USG%    TOr  ...  \
# 0     NaN     A.J. Price  Ind  PG   25  44  12.7  26.1  17.9  0.145  ...
# 1     NaN     Aaron Gray  Tor   C   27  49  16.4  33.8  13.6  0.219  ...
# 2     NaN  Al Harrington  Den  PF   31  64  27.3  56.2  24.5  0.116  ...
# 3     NaN     Al Horford  Atl   C   25  11  31.5  58.3  18.0  0.121  ...
# 4     NaN   Al Jefferson  Uta   C   27  61  33.8  68.9  25.9  0.052  ...
# ..    ...            ...  ...  ..  ...  ..   ...   ...   ...    ...  ...
# 395   NaN     Will Bynum  Det  PG   29  36  14.1  28.9  25.2  0.196  ...
# 396   NaN   Willie Green  Atl  SG   30  53  17.2  34.9  19.7  0.086  ...
# 397   NaN   Xavier Henry  Nor  SG   20  45  16.7  34.4  18.9  0.117  ...
# 398   NaN  Zach Randolph  Mem  PF   30  28  26.0  53.5  22.6  0.110  ...
# 399   NaN  Zaza Pachulia  Atl   C   27  58  28.1  57.1  14.2  0.165  ...
#
#        TS%   PPG  RPG  TRB%  APG  AST%   VI   SPG   BPG  Year
# ...

# %%
player_stats_1011 = pd.read_html("https://www.nbastuffer.com/2010-2011-nba-regular-season-player-stats/")[0]

player_stats_1011.columns = player_stats_1011.columns.droplevel()
player_stats_1011["Year"] = 2011

player_stats_1011.drop(columns=['Unnamed: 25_level_1'], inplace=True)
player_stats_1011
# Out:
#      Rank              PLAYER TEAM POS  AGE  GP   MPG  MIN%  USG%    TOr  ...  \
# 0     NaN       Arron Afflalo  Den  SG   25  69  33.5  69.6  14.9  0.092  ...
# 1     NaN         Alex Ajinca  Tor   C   22  24  10.8  22.1  21.5  0.136  ...
# 2     NaN     Al-Farouq Aminu  Lac  SF   20  81  17.7  36.6  17.5  0.183  ...
# 3     NaN     Andrea Bargnani  Tor   C   25  66  35.4  73.3  28.3  0.103  ...
# 4     NaN     Andris Biedrins  Gol   C   24  59  23.5  48.4  10.7  0.169  ...
# ..    ...                 ...  ...  ..  ...  ..   ...   ...   ...    ...  ...
# 411   NaN         Yi Jianlian  Was  PF   23  63  17.5  35.8  17.6  0.116  ...
# 412   NaN      Zabian Dowdell  Pho  PG   26  24  11.9  23.5  25.5  0.180  ...
# 413   NaN  Zydrunas Ilgauskas  Mia   C   35  72  15.7  32.5  16.2  0.133  ...
# 414   NaN       Zaza Pachulia  Atl   C   26  79  15.5  32.3  14.7  0.182  ...
# 415   NaN       Zach Randolph  Mem  PF   29  75  36.1  74.5  25.2  0.100  ...
#
# ...

# %%
player_stats_0910 = pd.read_html("https://www.nbastuffer.com/2009-2010-nba-regular-season-player-stats/")[0]

player_stats_0910.columns = player_stats_0910.columns.droplevel()
player_stats_0910["Year"] = 2010

player_stats_0910.drop(columns=['Unnamed: 24_level_1', 'Unnamed: 25_level_1'], inplace=True)
player_stats_0910
# Out:
#      Rank              PLAYER TEAM TRADE POS  AGE  GP  GM  GS   ORTG  ...  \
# 0     NaN       Arron Afflalo  Den   NaN  SG   24  82   0  75  114.3  ...
# 1     NaN     Andrea Bargnani  Tor   NaN   C   24  80   2  80  108.4  ...
# 2     NaN     Andris Biedrins  Gol   NaN   C   23  33  49  29  113.4  ...
# 3     NaN      Andray Blatche  Was   NaN  PF   23  81   1  36  101.4  ...
# 4     NaN        Andrew Bogut  Mil   NaN   C   24  69  13  69  107.4  ...
# ..    ...                 ...  ...   ...  ..  ...  ..  ..  ..    ...  ...
# 410   NaN     Wesley Matthews  Uta   NaN  SG   23  82   0  48  112.7  ...
# 411   NaN         Yi Jianlian  Njn   NaN  PF   22  52  30  51   99.0  ...
# 412   NaN  Zydrunas Ilgauskas  Cle     √   C   34  64  18   6  102.4  ...
# 413   NaN       Zaza Pachulia  Atl   NaN   C   25  78   4   2  109.6  ...
# 414   NaN       Zach Randolph  Mem   NaN  PF   28  81   1  81  113.8  ...
#
#      FTA    FT%   eFG%    TS%   MPG   PPG   RPG  APG   VI  Year
# ...

# %%
player_stats_0809 = pd.read_html("https://www.nbastuffer.com/2008-2009-nba-regular-season-player-stats/")[0]

player_stats_0809.columns = player_stats_0809.columns.droplevel([0,1])
player_stats_0809["Year"] = 2009

#player_stats_0809.drop(columns=['Unnamed: 25_level_1'], inplace=True)
player_stats_0809
# Out:
#      Rank       Player  Age Team Pos  GP  GM   Usg    FG%    FT%  ...   TOr  \
# 0     NaN    A.Afflalo   23  Det  SG  74   8  15.1  0.437  0.817  ...  10.3
# 1     NaN   A.Bargnani   23  Tor   C  78   4  23.1  0.450  0.831  ...  10.4
# 2     NaN   A.Biedrins   22  Gol   C  62  20  17.1  0.578  0.551  ...  12.8
# 3     NaN    A.Blatche   22  Was  PF  71  11  22.4  0.471  0.704  ...  12.5
# 4     NaN      A.Bogut   24  Mil   C  36  46  18.0  0.577  0.571  ...  16.6
# ..    ...          ...  ...  ...  ..  ..  ..   ...    ...    ...  ...   ...
# 345   NaN       Y.Ming   28  Hou   C  77   5  26.6  0.548  0.866  ...  14.6
# 346   NaN  Z.Ilgauskas   33  Cle   C  65  17  24.1  0.472  0.799  ...   9.4
# 347   NaN   Z.Pachulia   24  Atl   C  77   5  16.6  0.497  0.709  ...  16.1
# 348   NaN   Z.Randolph   27  Lac  PF  39  43  28.7  0.487  0.701  ...   9.7
# 349   NaN   Z.Randolph   27  Nyk  PF  11  71  27.4  0.434  0.821  ...   9.0
#
# ...

# %%
revised_player_names = []
for i in player_stats_0809["Player"]:
    revised_player_names.append(i[2:])

player_stats_0809["Player"] = revised_player_names
player_stats_0809
# Out:
#      Rank     Player  Age Team Pos  GP  GM   Usg    FG%    FT%  ...   Min  \
# 0     NaN    Afflalo   23  Det  SG  74   8  15.1  0.437  0.817  ...  16.1
# 1     NaN   Bargnani   23  Tor   C  78   4  23.1  0.450  0.831  ...  31.2
# 2     NaN   Biedrins   22  Gol   C  62  20  17.1  0.578  0.551  ...  29.8
# 3     NaN    Blatche   22  Was  PF  71  11  22.4  0.471  0.704  ...  23.5
# 4     NaN      Bogut   24  Mil   C  36  46  18.0  0.577  0.571  ...  31.0
# ..    ...        ...  ...  ...  ..  ..  ..   ...    ...    ...  ...   ...
# 345   NaN       Ming   28  Hou   C  77   5  26.6  0.548  0.866  ...  33.4
# 346   NaN  Ilgauskas   33  Cle   C  65  17  24.1  0.472  0.799  ...  27.0
# 347   NaN   Pachulia   24  Atl   C  77   5  16.6  0.497  0.709  ...  18.9
# 348   NaN   Randolph   27  Lac  PF  39  43  28.7  0.487  0.701  ...  34.9
# 349   NaN   Randolph   27  Nyk  PF  11  71  27.4  0.434  0.821  ...  35.0
#
#      M.Diff.   Pts  P.Diff.   Rbd  R.Diff.  Ast  A.Diff.  Year  Allstar
# ...

# %%
allstar_0809 = pd.read_html("https://basketball.realgm.com/nba/allstar/game/rosters/2009")
allstar_0809_west = allstar_0809[8]
allstar_0809_east = allstar_0809[9]

allstar_0809_concat = pd.concat([allstar_0809_west, allstar_0809_east])
allstar_0809_concat
# Out:
#                Player Pos    HT   WT                    Team  \
# 0    Chauncey Billups   G   6-3  210          Denver Nuggets
# 1         Kobe Bryant  SG   6-6  212      Los Angeles Lakers
# 2          Tim Duncan  FC  6-11  250       San Antonio Spurs
# 3           Pau Gasol  FC   7-0  250      Los Angeles Lakers
# 4            Yao Ming   C   7-6  310         Houston Rockets
# 5       Dirk Nowitzki  PF   7-0  245        Dallas Mavericks
# 6    Shaquille O'Neal   C   7-1  325            Phoenix Suns
# 7         Tony Parker   G   6-2  185       San Antonio Spurs
# 8          Chris Paul  PG   6-0  175     New Orleans Hornets
# 9         Brandon Roy   G   6-6  211  Portland Trail Blazers
# 10  Amar'e Stoudemire  FC  6-10  245            Phoenix Suns
# 11         David West  PF   6-9  250     New Orleans Hornets
# 0           Ray Allen  SG   6-5  205          Boston Celtics
# 1          Chris Bosh  PF  6-11  235         Toronto Raptors
# ...

# %%
allstar_0910 = pd.read_html("https://basketball.realgm.com/nba/allstar/game/rosters/2010")
allstar_0910_west = allstar_0910[8]
allstar_0910_east = allstar_0910[9]

allstar_0910_concat = pd.concat([allstar_0910_west, allstar_0910_east])
allstar_0910_concat
# Out:
#                Player Pos    HT   WT                    Team  \
# 0     Carmelo Anthony   F   6-8  240          Denver Nuggets
# 1    Chauncey Billups   G   6-3  210          Denver Nuggets
# 2         Kobe Bryant  SG   6-6  212      Los Angeles Lakers
# 3          Tim Duncan  FC  6-11  250       San Antonio Spurs
# 4        Kevin Durant  SF  6-10  225   Oklahoma City Thunder
# 5           Pau Gasol  FC   7-0  250      Los Angeles Lakers
# 6         Chris Kaman   C   7-0  265    Los Angeles Clippers
# 7          Jason Kidd  PG   6-4  210        Dallas Mavericks
# 8          Steve Nash   G   6-3  178            Phoenix Suns
# 9       Dirk Nowitzki  PF   7-0  245        Dallas Mavericks
# 10         Chris Paul  PG   6-0  175     New Orleans Hornets
# 11      Zach Randolph  PF   6-9  260       Memphis Grizzlies
# 12        Brandon Roy   G   6-6  211  Portland Trail Blazers
# 13  Amar'e Stoudemire  FC  6-10  245            Phoenix Suns
# ...

# %%
allstar_1011 = pd.read_html("https://basketball.realgm.com/nba/allstar/game/rosters/2011")
allstar_1011_west = allstar_1011[8]
allstar_1011_east = allstar_1011[9]

allstar_1011_concat = pd.concat([allstar_1011_west, allstar_1011_east])
allstar_1011_concat
# Out:
#                Player Pos    HT   WT                    Team  \
# 0     Carmelo Anthony   F   6-8  240          Denver Nuggets
# 1         Kobe Bryant  SG   6-6  212      Los Angeles Lakers
# 2          Tim Duncan  FC  6-11  250       San Antonio Spurs
# 3        Kevin Durant  SF  6-10  225   Oklahoma City Thunder
# 4           Pau Gasol  FC   7-0  250      Los Angeles Lakers
# 5       Manu Ginobili  SG   6-6  205       San Antonio Spurs
# 6       Blake Griffin  PF   6-9  246    Los Angeles Clippers
# 7          Kevin Love  FC   6-8  247  Minnesota Timberwolves
# 8            Yao Ming   C   7-6  310         Houston Rockets
# 9       Dirk Nowitzki  PF   7-0  245        Dallas Mavericks
# 10         Chris Paul  PG   6-0  175     New Orleans Hornets
# 11  Russell Westbrook   G   6-3  200   Oklahoma City Thunder
# 12     Deron Williams  PG   6-3  200               Utah Jazz
# 0           Ray Allen  SG   6-5  205          Boston Celtics
# ...

# %%
allstar_1112 = pd.read_html("https://basketball.realgm.com/nba/allstar/game/rosters/2012")
allstar_1112_west = allstar_1112[8]
allstar_1112_east = allstar_1112[9]

allstar_1112_concat = pd.concat([allstar_1112_west, allstar_1112_east])
allstar_1112_concat
# Out:
#                Player Pos    HT   WT                    Team  \
# 0     Carmelo Anthony   F   6-8  240         New York Knicks
# 1          Chris Bosh  PF  6-11  235              Miami Heat
# 2           Luol Deng  GF   6-9  220           Chicago Bulls
# 3         Roy Hibbert   C   7-2  270          Indiana Pacers
# 4       Dwight Howard   C  6-11  265           Orlando Magic
# 5      Andre Iguodala  SF   6-6  215     Philadelphia Sixers
# 6        LeBron James   F   6-8  250              Miami Heat
# 7         Joe Johnson  SG   6-7  240           Atlanta Hawks
# 8         Paul Pierce  SF   6-7  235          Boston Celtics
# 9         Rajon Rondo  PG   6-1  180          Boston Celtics
# 10       Derrick Rose  PG   6-3  200           Chicago Bulls
# 11        Dwyane Wade  SG   6-4  220              Miami Heat
# 12     Deron Williams  PG   6-3  200         New Jersey Nets
# 0   LaMarcus Aldridge  FC  6-11  265  Portland Trail Blazers
# ...

# %%
allstar_1213 = pd.read_html("https://basketball.realgm.com/nba/allstar/game/rosters/2013")
allstar_1213_west = allstar_1213[8]
allstar_1213_east = allstar_1213[9]

allstar_1213_concat = pd.concat([allstar_1213_west, allstar_1213_east])
allstar_1213_concat
# Out:
#                Player Pos    HT   WT                    Team  \
# 0   LaMarcus Aldridge  FC  6-11  265  Portland Trail Blazers
# 1         Kobe Bryant  SG   6-6  212      Los Angeles Lakers
# 2          Tim Duncan  FC  6-11  250       San Antonio Spurs
# 3        Kevin Durant  SF  6-10  225   Oklahoma City Thunder
# 4       Blake Griffin  PF   6-9  246    Los Angeles Clippers
# 5        James Harden  SG   6-5  220         Houston Rockets
# 6       Dwight Howard   C  6-11  265      Los Angeles Lakers
# 7           David Lee  FC   6-9  245   Golden State Warriors
# 8         Tony Parker   G   6-2  185       San Antonio Spurs
# 9          Chris Paul  PG   6-0  175    Los Angeles Clippers
# 10      Zach Randolph  PF   6-9  260       Memphis Grizzlies
# 11  Russell Westbrook   G   6-3  200   Oklahoma City Thunder
# 0     Carmelo Anthony   F   6-8  240         New York Knicks
# 1          Chris Bosh  PF  6-11  235              Miami Heat
# ...

# %%
allstar_1314 = pd.read_html("https://basketball.realgm.com/nba/allstar/game/rosters/2014")
allstar_1314_west = allstar_1314[8]
allstar_1314_east = allstar_1314[9]

allstar_1314_concat = pd.concat([allstar_1314_west, allstar_1314_east])
allstar_1314_concat
# Out:
#                Player Pos    HT   WT                    Team  \
# 0   LaMarcus Aldridge  FC  6-11  265  Portland Trail Blazers
# 1         Kobe Bryant  SG   6-6  212      Los Angeles Lakers
# 2       Stephen Curry   G   6-3  198   Golden State Warriors
# 3       Anthony Davis  PF  6-10  253    New Orleans Pelicans
# 4        Kevin Durant  SF  6-10  225   Oklahoma City Thunder
# 5       Blake Griffin  PF   6-9  246    Los Angeles Clippers
# 6        James Harden  SG   6-5  220         Houston Rockets
# 7       Dwight Howard   C  6-11  265         Houston Rockets
# 8      Damian Lillard   G   6-2  200  Portland Trail Blazers
# 9          Kevin Love  FC   6-8  247  Minnesota Timberwolves
# 10      Dirk Nowitzki  PF   7-0  245        Dallas Mavericks
# 11        Tony Parker   G   6-2  185       San Antonio Spurs
# 12         Chris Paul  PG   6-0  175    Los Angeles Clippers
# 0     Carmelo Anthony   F   6-8  240         New York Knicks
# ...

# %%
allstar_1415 = pd.read_html("https://basketball.realgm.com/nba/allstar/game/rosters/2015")
allstar_1415_west = allstar_1415[8]
allstar_1415_east = allstar_1415[9]

allstar_1415_concat = pd.concat([allstar_1415_west, allstar_1415_east])
allstar_1415_concat
# Out:
#                Player Pos    HT   WT                    Team  \
# 0     Carmelo Anthony   F   6-8  240         New York Knicks
# 1          Chris Bosh  PF  6-11  235              Miami Heat
# 2        Jimmy Butler  GF   6-8  232           Chicago Bulls
# 3           Pau Gasol  FC   7-0  250           Chicago Bulls
# 4          Al Horford  FC   6-9  240           Atlanta Hawks
# 5        Kyrie Irving   G   6-2  191     Cleveland Cavaliers
# 6        LeBron James   F   6-8  250     Cleveland Cavaliers
# 7         Kyle Korver  SF   6-7  212           Atlanta Hawks
# 8          Kyle Lowry  PG   6-1  196         Toronto Raptors
# 9        Paul Millsap  FC   6-7  250           Atlanta Hawks
# 10        Jeff Teague  PG   6-3  195           Atlanta Hawks
# 11        Dwyane Wade  SG   6-4  220              Miami Heat
# 12          John Wall  PG   6-3  210      Washington Wizards
# 0   LaMarcus Aldridge  FC  6-11  265  Portland Trail Blazers
# ...

# %%
allstar_1516 = pd.read_html("https://basketball.realgm.com/nba/allstar/game/rosters/2016")
allstar_1516_west = allstar_1516[8]
allstar_1516_east = allstar_1516[9]

allstar_1516_concat = pd.concat([allstar_1516_west, allstar_1516_east])
allstar_1516_concat
# Out:
#                Player Pos    HT   WT                   Team  \
# 0     Carmelo Anthony   F   6-8  240        New York Knicks
# 1          Chris Bosh  PF  6-11  235             Miami Heat
# 2        Jimmy Butler  GF   6-8  232          Chicago Bulls
# 3       DeMar DeRozan  GF   6-6  220        Toronto Raptors
# 4      Andre Drummond   C  6-10  279        Detroit Pistons
# 5           Pau Gasol  FC   7-0  250          Chicago Bulls
# 6         Paul George  GF   6-8  220         Indiana Pacers
# 7          Al Horford  FC   6-9  240          Atlanta Hawks
# 8        LeBron James   F   6-8  250    Cleveland Cavaliers
# 9          Kyle Lowry  PG   6-1  196        Toronto Raptors
# 10       Paul Millsap  FC   6-7  250          Atlanta Hawks
# 11      Isaiah Thomas  PG   5-9  185         Boston Celtics
# 12        Dwyane Wade  SG   6-4  220             Miami Heat
# 13          John Wall  PG   6-3  210     Washington Wizards
# 0   LaMarcus Aldridge  FC  6-11  265      San Antonio Spurs
# ...

# %%
allstar_1617 = pd.read_html("https://basketball.realgm.com/nba/allstar/game/rosters/2017")
allstar_1617_west = allstar_1617[8]
allstar_1617_east = allstar_1617[9]

allstar_1617_concat = pd.concat([allstar_1617_west, allstar_1617_east])
allstar_1617_concat
# Out:
#                    Player Pos    HT   WT                   Team  \
# 0        DeMarcus Cousins   C  6-11  270       Sacramento Kings
# 1           Stephen Curry   G   6-3  198  Golden State Warriors
# 2           Anthony Davis  PF  6-10  253   New Orleans Pelicans
# 3            Kevin Durant  SF  6-10  225  Golden State Warriors
# 4              Marc Gasol   C   7-1  255      Memphis Grizzlies
# 5          Draymond Green   F   6-6  234  Golden State Warriors
# 6            James Harden  SG   6-5  220        Houston Rockets
# 7          Gordon Hayward  GF   6-7  225              Utah Jazz
# 8          DeAndre Jordan   C  6-11  265   Los Angeles Clippers
# 9           Kawhi Leonard   F   6-7  225      San Antonio Spurs
# 10          Klay Thompson   G   6-6  210  Golden State Warriors
# 11      Russell Westbrook   G   6-3  200  Oklahoma City Thunder
# 0   Giannis Antetokounmpo   F  6-11  242        Milwaukee Bucks
# 1         Carmelo Anthony   F   6-8  240        New York Knicks
# ...

# %%
allstar_1718 = pd.read_html("https://basketball.realgm.com/nba/allstar/game/rosters/2018")
allstar_1718_west = allstar_1718[8]
allstar_1718_east = allstar_1718[9]

allstar_1718_concat = pd.concat([allstar_1718_west, allstar_1718_east])
allstar_1718_concat
# Out:
#                    Player Pos    HT   WT                    Team  \
# 0   Giannis Antetokounmpo   F  6-11  242         Milwaukee Bucks
# 1            Jimmy Butler  GF   6-8  232  Minnesota Timberwolves
# 2           Stephen Curry   G   6-3  198   Golden State Warriors
# 3           DeMar DeRozan  GF   6-6  220         Toronto Raptors
# 4             Joel Embiid   C   7-0  280     Philadelphia Sixers
# 5          Draymond Green   F   6-6  234   Golden State Warriors
# 6            James Harden  SG   6-5  220         Houston Rockets
# 7              Al Horford  FC   6-9  240          Boston Celtics
# 8          Damian Lillard   G   6-2  200  Portland Trail Blazers
# 9              Kyle Lowry  PG   6-1  196         Toronto Raptors
# 10          Klay Thompson   G   6-6  210   Golden State Warriors
# 11     Karl-Anthony Towns   C   7-0  250  Minnesota Timberwolves
# 0       LaMarcus Aldridge  FC  6-11  265       San Antonio Spurs
# ...

# %%
allstar_1819 = pd.read_html("https://basketball.realgm.com/nba/allstar/game/rosters/2019")
allstar_1819_west = allstar_1819[8]
allstar_1819_east = allstar_1819[9]

allstar_1819_concat = pd.concat([allstar_1819_west, allstar_1819_east])
allstar_1819_concat
# Out:
#                    Player Pos    HT   WT                    Team  \
# 0       LaMarcus Aldridge  FC  6-11  265       San Antonio Spurs
# 1            Bradley Beal  SG   6-3  207      Washington Wizards
# 2           Anthony Davis  PF  6-10  253    New Orleans Pelicans
# 3            Kevin Durant  SF  6-10  225   Golden State Warriors
# 4            James Harden  SG   6-5  220         Houston Rockets
# 5            Kyrie Irving   G   6-2  191          Boston Celtics
# 6            LeBron James   F   6-8  250      Los Angeles Lakers
# 7           Kawhi Leonard   F   6-7  225         Toronto Raptors
# 8          Damian Lillard   G   6-2  200  Portland Trail Blazers
# 9             Ben Simmons  PF  6-10  240     Philadelphia Sixers
# 10          Klay Thompson   G   6-6  210   Golden State Warriors
# 11     Karl-Anthony Towns   C   7-0  250  Minnesota Timberwolves
# 12            Dwyane Wade  SG   6-4  220              Miami Heat
# ...

# %%
allstar_1920 = pd.read_html("https://basketball.realgm.com/nba/allstar/game/rosters/2020")
allstar_1920_west = allstar_1920[8]
allstar_1920_east = allstar_1920[9]

allstar_1920_concat = pd.concat([allstar_1920_west, allstar_1920_east])
allstar_1920_concat
# Out:
#                    Player Pos    HT   WT                    Team  \
# 0            Devin Booker  SG   6-6  206            Phoenix Suns
# 1           Anthony Davis  PF  6-10  253      Los Angeles Lakers
# 2             Luka Doncic  SF   6-7  230        Dallas Mavericks
# 3            James Harden  SG   6-5  220         Houston Rockets
# 4            LeBron James   F   6-8  250      Los Angeles Lakers
# 5            Nikola Jokic   C   7-0  284          Denver Nuggets
# 6           Kawhi Leonard   F   6-7  225    Los Angeles Clippers
# 7          Damian Lillard   G   6-2  200  Portland Trail Blazers
# 8              Chris Paul  PG   6-0  175   Oklahoma City Thunder
# 9        Domantas Sabonis  PF  6-11  240          Indiana Pacers
# 10            Ben Simmons  PF  6-10  240     Philadelphia Sixers
# 11           Jayson Tatum  SF   6-8  210          Boston Celtics
# 12      Russell Westbrook   G   6-3  200         Houston Rockets
# ...

# %%
allstar_2021 = pd.read_html("https://basketball.realgm.com/nba/allstar/game/rosters/2021")
allstar_2021_west = allstar_2021[8]
allstar_2021_east = allstar_2021[9]

allstar_2021_concat = pd.concat([allstar_2021_west, allstar_2021_east])
allstar_2021_concat
# Out:
#                    Player Pos    HT   WT                    Team  \
# 0            Bradley Beal  SG   6-3  207      Washington Wizards
# 1            Devin Booker  SG   6-6  206            Phoenix Suns
# 2             Mike Conley  PG   6-1  175               Utah Jazz
# 3            Kevin Durant  SF  6-10  225           Brooklyn Nets
# 4             Joel Embiid   C   7-0  280     Philadelphia Sixers
# 5            James Harden  SG   6-5  220           Brooklyn Nets
# 6            Kyrie Irving   G   6-2  191           Brooklyn Nets
# 7             Zach LaVine  SG   6-5  200           Chicago Bulls
# 8           Kawhi Leonard   F   6-7  225    Los Angeles Clippers
# 9        Donovan Mitchell  SG   6-3  215               Utah Jazz
# 10          Julius Randle  PF   6-9  250         New York Knicks
# 11           Jayson Tatum  SF   6-8  210          Boston Celtics
# 12         Nikola Vucevic  PF  6-11  260           Orlando Magic
# ...

# %%
allstar_2122 = pd.read_html("https://basketball.realgm.com/nba/allstar/game/rosters/2022")
allstar_2122_west = allstar_2122[8]
allstar_2122_east = allstar_2122[9]

allstar_2122_concat = pd.concat([allstar_2122_west, allstar_2122_east])
allstar_2122_concat
# Out:
#                    Player Pos    HT   WT                    Team  \
# 0           Jarrett Allen   C  6-11  248     Cleveland Cavaliers
# 1   Giannis Antetokounmpo   F  6-11  242         Milwaukee Bucks
# 2            Jimmy Butler  GF   6-8  232              Miami Heat
# 3           Stephen Curry   G   6-3  198   Golden State Warriors
# 4           DeMar DeRozan  GF   6-6  220           Chicago Bulls
# 5             Luka Doncic  SF   6-7  230        Dallas Mavericks
# 6          Darius Garland   G   6-1  186     Cleveland Cavaliers
# 7          Draymond Green   F   6-6  234   Golden State Warriors
# 8            James Harden  SG   6-5  220     Philadelphia Sixers
# 9            LeBron James   F   6-8  250      Los Angeles Lakers
# 10           Nikola Jokic   C   7-0  284          Denver Nuggets
# 11       Donovan Mitchell  SG   6-3  215               Utah Jazz
# 12             Chris Paul  PG   6-0  175            Phoenix Suns
# ...

# %%
allstar_2223 = pd.read_html("https://basketball.realgm.com/nba/allstar/game/rosters/2023")
allstar_2223_west = allstar_2223[8]
allstar_2223_east = allstar_2223[9]

allstar_2223_concat = pd.concat([allstar_2223_west, allstar_2223_east])
allstar_2223_concat
# Out:
#                      Player Pos    HT   WT                    Team  \
# 0              Jaylen Brown  SF   6-6  220          Boston Celtics
# 1             Stephen Curry   G   6-3  198   Golden State Warriors
# 2               Luka Doncic  SF   6-7  230        Dallas Mavericks
# 3           Anthony Edwards  SF   6-5  229  Minnesota Timberwolves
# 4               Joel Embiid   C   7-0  280     Philadelphia Sixers
# 5              De'Aaron Fox  PG   6-3  185        Sacramento Kings
# 6               Paul George  GF   6-8  220    Los Angeles Clippers
# 7         Tyrese Haliburton  PG   6-5  185          Indiana Pacers
# 8              Kyrie Irving   G   6-2  191        Dallas Mavericks
# 9        Jaren Jackson, Jr.  PF  6-11  242       Memphis Grizzlies
# 10             LeBron James   F   6-8  250      Los Angeles Lakers
# 11             Nikola Jokic   C   7-0  284          Denver Nuggets
# 12            Julius Randle  PF   6-9  250         New York Knicks
# ...

# %%
empty_list_allstar23 = []
for i in player_stats_2223["NAME"]:
    if i in list(allstar_2223_concat["Player"]):
        empty_list_allstar23.append(1)
    else:
        empty_list_allstar23.append(0)
        
#print(sum(empty_list_allstar23))

player_stats_2223["Allstar"] = empty_list_allstar23

player_stats_2223[player_stats_2223["Allstar"] == 1]
# Out:
#                          NAME TEAM  POS   AGE  GP   MPG  USG%   TO%  FTA  \
# RANK
# 20               Jayson Tatum  Bos  F-G  25.0  57  37.4  32.9  12.1  485
# 21               Jaylen Brown  Bos  G-F  26.3  50  35.7  31.6  13.1  274
# 37               Kyrie Irving  Bro    G  30.9  40  36.9  29.9  10.0  179
# 38               Kevin Durant  Bro    F  34.4  39  36.0  31.7  15.6  285
# 76              DeMar DeRozan  Chi  G-F  33.6  55  36.1  28.3  10.9  405
# 94           Donovan Mitchell  Cle    G  26.5  53  35.4  31.4  12.0  275
# 110              Kyrie Irving  Dal    G  30.9   6  36.9  27.7  11.3   25
# 111               Luka Doncic  Dal  F-G  24.0  52  36.4  38.2  14.2  571
# 133              Nikola Jokic  Den    C  28.0  54  33.7  27.3  19.3  336
# 172             Stephen Curry  Gol    G  35.0  38  34.6  30.8  14.0  206
# 206         Tyrese Haliburton  Ind    G  23.0  50  33.6  23.5  14.8  156
# 225               Paul George  Lac    F  32.8  46  34.4  29.3  15.9  232
# ...

# %%
empty_list_allstar22 = []
for i in player_stats_2122["FULL NAME"]:
    if i in list(allstar_2122_concat["Player"]):
        empty_list_allstar22.append(1)
    else:
        empty_list_allstar22.append(0)
        
player_stats_2122["Allstar"] = empty_list_allstar22

player_stats_2122[player_stats_2122["Allstar"] == 1]
# Out:
#                   FULL NAME TEAM  POS    AGE  GP   MPG  MIN%  USG%   TO%  FTA  \
# RANK
# 9             Jarrett Allen  Cle    C  23.97  56  32.3  67.3  18.1  12.7  233
# 14    Giannis Antetokounmpo  Mil    F  27.35  67  32.9  68.5  34.9  12.2  766
# 29              LaMelo Ball  Cha    G  20.64  75  32.3  67.3  28.2  15.3  243
# 65             Devin Booker  Pho    G  25.44  68  34.5  71.8  32.0   9.3  363
# 97             Jimmy Butler  Mia    F  32.57  57  33.9  70.6  26.5  10.5  455
# 143           Stephen Curry  Gol    G  34.07  64  34.6  72.0  30.8  13.2  298
# 151           DeMar DeRozan  Chi  G-F  32.68  76  36.1  75.2  31.8   9.2  593
# 160             Luka Doncic  Dal  F-G  23.12  65  35.4  73.7  37.4  15.3  489
# 177            Kevin Durant  Bro    F  33.53  55  37.2  77.6  31.2  12.9  409
# 185             Joel Embiid  Phi  C-F  28.07  68  33.8  70.4  37.2  11.3  803
# 217          Darius Garland  Cle    G  22.21  68  35.7  74.4  27.8  16.2  241
# ...

# %%
empty_list_allstar21 = []
for i in player_stats_2021["FULL NAME"]:
    if i in list(allstar_2021_concat["Player"]):
        empty_list_allstar21.append(1)
    else:
        empty_list_allstar21.append(0)
        
player_stats_2021["Allstar"] = empty_list_allstar21

player_stats_2021[player_stats_2021["Allstar"] == 1]
# Out:
#                   FULL NAME TEAM  POS    AGE  GP   MPG  MIN%  USG%   TO%  FTA  \
# RANK
# 15    Giannis Antetokounmpo  Mil    F  26.44  61  33.0  68.7  32.5  13.2  581
# 42             Bradley Beal  Was    G  27.89  60  35.8  74.5  34.1  10.6  459
# 65             Devin Booker  Pho    G  24.54  67  33.9  70.6  32.7  12.4  392
# 87             Jaylen Brown  Bos  G-F  24.56  58  34.5  71.8  29.7  11.5  250
# 121             Mike Conley  Uta    G  33.60  51  29.4  61.2  23.1  12.4  142
# 135           Stephen Curry  Gol    G  33.17  63  34.2  71.1  34.8  12.2  395
# 137           Anthony Davis  Lal  F-C  28.18  36  32.3  67.2  29.2   9.5  214
# 152             Luka Doncic  Dal  F-G  22.21  66  34.3  71.4  36.0  15.3  471
# 163            Kevin Durant  Bro    F  32.63  35  33.1  68.9  31.2  14.5  238
# 169             Joel Embiid  Phi  C-F  27.17  51  31.1  64.8  35.3  12.2  548
# 199             Paul George  Lac    F  31.04  54  33.7  70.3  30.0  14.5  228
# ...

# %%
empty_list_allstar20 = []
for i in player_stats_1920["FULL NAME"]:
    if i in list(allstar_1920_concat["Player"]):
        empty_list_allstar20.append(1)
    else:
        empty_list_allstar20.append(0)
        
player_stats_1920["Allstar"] = empty_list_allstar20

player_stats_1920[player_stats_1920["Allstar"] == 1]
# Out:
#                   FULL NAME TEAM  POS    AGE  GP   MPG  MIN%  USG%   TO%  FTA  \
# RANK
# 2               Bam Adebayo  Mia  C-F  23.08  72  33.6  69.9  21.2  17.5  382
# 13    Giannis Antetokounmpo  Mil    F  25.69  63  30.4  63.4  37.5  13.2  629
# 62             Devin Booker  Pho    G  23.79  70  35.9  74.8  30.0  14.9  509
# 91             Jimmy Butler  Mia    F  30.92  58  33.8  70.4  25.1  11.4  525
# 143           Anthony Davis  Lal  F-C  27.43  62  34.4  71.6  29.3  10.4  525
# 156             Luka Doncic  Dal  G-F  21.46  61  33.6  69.9  36.8  14.8  562
# 169             Joel Embiid  Phi  C-F  26.42  51  29.5  61.5  33.0  13.8  436
# 203             Rudy Gobert  Uta    C  28.13  68  34.3  71.5  16.2  15.0  403
# 228            James Harden  Hou    G  30.97  68  36.5  76.1  36.2  14.0  800
# 274          Brandon Ingram  Nor    F  22.95  62  33.9  70.7  28.1  13.0  368
# 285            LeBron James  Lal    F  35.62  67  34.6  72.0  31.5  15.1  381
# ...

# %%
empty_list_allstar19 = []
for i in player_stats_1819["FULL NAME"]:
    if i in list(allstar_1819_concat["Player"]):
        empty_list_allstar19.append(1)
    else:
        empty_list_allstar19.append(0)
        
player_stats_1819["Allstar"] = empty_list_allstar19

player_stats_1819[player_stats_1819["Allstar"] == 1]
# Out:
#                   FULL NAME TEAM  POS    AGE  GP   MPG  MIN%  USG%  Tor%  FTA  \
# RANK
# 8         LaMarcus Aldridge  San    F  33.73  81  33.2  69.1  27.0   8.8  412
# 19    Giannis Antetokounmpo  Mil    F  24.35  72  32.8  68.2  32.3  14.7  686
# 44             Bradley Beal  Was    G  25.79  82  36.9  76.9  28.4  11.0  448
# 143           Stephen Curry  Gol    G  31.07  69  33.8  70.4  30.4  11.6  287
# 145           Anthony Davis  Nor  F-C  26.09  56  33.0  68.8  29.5   8.5  433
# 172            Kevin Durant  Gol    F  30.53  78  34.6  72.2  29.0  12.2  506
# 179             Joel Embiid  Phi  F-C  25.07  64  33.7  70.1  33.3  13.3  649
# 213             Paul George  Okc    F  28.94  77  36.9  76.9  29.5  10.0  539
# 233           Blake Griffin  Det    F  30.07  75  35.0  72.8  30.2  13.8  550
# 238            James Harden  Hou    G  29.63  78  36.8  76.6  40.5  14.5  858
# 286            Kyrie Irving  Bos    G  27.05  67  33.0  68.8  29.6  11.3  245
# ...

# %%
empty_list_allstar18 = []
for i in player_stats_1718["FULL NAME"]:
    if i in list(allstar_1718_concat["Player"]):
        empty_list_allstar18.append(1)
    else:
        empty_list_allstar18.append(0)
        
player_stats_1718["Allstar"] = empty_list_allstar18

player_stats_1718[player_stats_1718["Allstar"] == 1]
# Out:
#                   FULL NAME TEAM POS   AGE  GP   MPG  MIN%  USG%   Tor%  FTA  \
# RANK
# NaN              Al Horford  Bos   C  31.0  72  31.6  65.9  18.4  0.141  120
# NaN          Andre Drummond  Det   C  24.0  78  33.7  70.1  21.2  0.159  395
# NaN           Anthony Davis  Nor  PF  24.0  75  36.4  75.8  30.0  0.086  598
# NaN            Bradley Beal  Was  SG  24.0  82  36.3  75.6  27.6  0.115  369
# NaN          Damian Lillard  Por  PG  27.0  73  36.6  76.2  30.6  0.111  538
# NaN           DeMar DeRozan  Tor  SG  28.0  80  33.9  70.6  29.6  0.096  559
# NaN        DeMarcus Cousins  Nor   C  27.0  48  36.2  75.4  31.9  0.189  394
# NaN          Draymond Green  Gol  PF  27.0  70  32.7  68.1  17.2  0.225  173
# NaN   Giannis Antetokounmpo  Mil  PF  23.0  75  36.8  76.6  31.2  0.117  641
# NaN            Goran Dragic  Mia  PG  31.0  75  31.7  66.0  25.7  0.122  271
# NaN            James Harden  Hou  PG  28.0  72  35.4  73.8  36.0  0.151  727
# ...

# %%
empty_list_allstar17 = []
for i in player_stats_1617["PLAYER"]:
    if i in list(allstar_1617_concat["Player"]):
        empty_list_allstar17.append(1)
    else:
        empty_list_allstar17.append(0)
        
player_stats_1617["Allstar"] = empty_list_allstar17

player_stats_1617[player_stats_1617["Allstar"] == 1]
# Out:
#      Rank             PLAYER TEAM POS  AGE  GP   MPG  MIN%  USG%    TOr  ...  \
# 29    NaN      Anthony Davis  Nor   C   23  75  36.1  75.2  32.6  0.091  ...
# 67    NaN    Carmelo Anthony  Nyk  SF   32  74  34.3  71.5  29.1  0.090  ...
# 106   NaN     DeAndre Jordan  Lac   C   28  81  31.7  66.1  15.3  0.132  ...
# 110   NaN      DeMar DeRozan  Tor  SG   27  74  35.4  73.8  34.3  0.090  ...
# 111   NaN   DeMarcus Cousins  Sac   C   26  55  34.4  71.6  37.5  0.132  ...
# 112   NaN   DeMarcus Cousins  Nor   C   26  17  33.8  70.4  33.1  0.144  ...
# 135   NaN     Draymond Green  Gol  PF   26  76  32.5  67.7  16.2  0.198  ...
# 165   NaN     Gordon Hayward  Uta  SF   26  73  34.5  71.8  27.6  0.094  ...
# 179   NaN      Isaiah Thomas  Bos  PG   27  76  33.8  70.4  34.0  0.107  ...
# 193   NaN       James Harden  Hou  PG   27  81  36.4  75.8  34.3  0.194  ...
# 217   NaN       Jimmy Butler  Chi  SF   27  76  37.0  77.0  26.5  0.093  ...
# ...

# %%
empty_list_allstar16 = []
for i in player_stats_1516["PLAYER"]:
    if i in list(allstar_1516_concat["Player"]):
        empty_list_allstar16.append(1)
    else:
        empty_list_allstar16.append(0)
        
player_stats_1516["Allstar"] = empty_list_allstar16

player_stats_1516[player_stats_1516["Allstar"] == 1]
# Out:
#      Rank             PLAYER TEAM POS  AGE  GP   MPG  MIN%  USG%    TOr  ...  \
# 3     NaN         Al Horford  Atl   C   29  82  32.1  66.9  20.6  0.088  ...
# 18    NaN     Andre Drummond  Det   C   22  81  32.9  68.6  24.1  0.105  ...
# 29    NaN      Anthony Davis  Nor  PF   22  61  35.5  73.9  29.6  0.084  ...
# 64    NaN    Carmelo Anthony  Nyk  SF   31  72  35.1  73.2  29.7  0.106  ...
# 75    NaN         Chris Bosh  Mia  PF   31  53  33.5  69.9  24.7  0.081  ...
# 80    NaN         Chris Paul  Lac  PG   30  74  32.7  68.1  27.1  0.134  ...
# 114   NaN      DeMar DeRozan  Tor  SG   26  78  35.9  74.9  29.8  0.095  ...
# 115   NaN   DeMarcus Cousins  Sac   C   25  65  34.6  72.0  35.4  0.133  ...
# 131   NaN     Draymond Green  Gol  PF   25  81  34.7  72.2  18.8  0.212  ...
# 135   NaN        Dwyane Wade  Mia  SG   34  74  30.5  63.6  31.7  0.130  ...
# 176   NaN      Isaiah Thomas  Bos  PG   26  82  32.2  67.2  29.7  0.119  ...
# ...

# %%
empty_list_allstar15 = []
for i in player_stats_1415["PLAYER"]:
    if i in list(allstar_1415_concat["Player"]):
        empty_list_allstar15.append(1)
    else:
        empty_list_allstar15.append(0)
        
player_stats_1415["Allstar"] = empty_list_allstar15

player_stats_1415[player_stats_1415["Allstar"] == 1]
# Out:
#      Rank             PLAYER TEAM POS  AGE  GP   MPG  MIN%  USG%    TOr  ...  \
# 7     NaN         Al Horford  Atl   C   28  76  30.5  63.5  22.6  0.089  ...
# 36    NaN      Anthony Davis  Nor  PF   21  68  36.1  75.2  28.3  0.063  ...
# 55    NaN      Blake Griffin  Lac  PF   25  67  35.2  73.3  28.8  0.102  ...
# 75    NaN    Carmelo Anthony  Nyk  SF   30  40  35.7  74.4  32.7  0.089  ...
# 84    NaN         Chris Bosh  Mia   C   30  44  35.4  73.7  28.9  0.101  ...
# 91    NaN         Chris Paul  Lac  PG   29  82  34.8  72.6  24.0  0.126  ...
# 106   NaN     Damian Lillard  Por  PG   24  82  35.7  74.3  27.2  0.126  ...
# 123   NaN   DeMarcus Cousins  Sac   C   24  59  34.1  71.1  34.6  0.163  ...
# 135   NaN      Dirk Nowitzki  Dal  PF   36  77  29.6  61.7  25.3  0.065  ...
# 146   NaN        Dwyane Wade  Mia  SG   33  62  31.8  66.2  35.3  0.144  ...
# 220   NaN       James Harden  Hou  SG   25  81  36.8  76.7  31.8  0.149  ...
# ...

# %%
empty_list_allstar14 = []
for i in player_stats_1314["PLAYER"]:
    if i in list(allstar_1314_concat["Player"]):
        empty_list_allstar14.append(1)
    else:
        empty_list_allstar14.append(0)
        
player_stats_1314["Allstar"] = empty_list_allstar14

player_stats_1314[player_stats_1314["Allstar"] == 1]
# Out:
#      Rank             PLAYER TEAM POS  AGE  GP   MPG  MIN%  USG%    TOr  ...  \
# 8     NaN  LaMarcus Aldridge  Por  PF   28  69  36.0  74.3  29.9  0.072  ...
# 20    NaN    Carmelo Anthony  Nyk  PF   29  77  38.5  79.5  32.6  0.095  ...
# 65    NaN         Chris Bosh  Mia   C   29  79  31.9  65.7  22.8  0.104  ...
# 77    NaN        Kobe Bryant  Lal  SG   35   6  29.4  60.2  28.8  0.292  ...
# 122   NaN      Stephen Curry  Gol  PG   25  78  36.3  75.0  28.4  0.161  ...
# 127   NaN      Anthony Davis  Nor   C   20  67  35.0  72.1  25.3  0.083  ...
# 139   NaN      DeMar DeRozan  Tor  SG   24  79  38.0  78.0  28.2  0.095  ...
# 150   NaN       Kevin Durant  Okc  SF   25  81  38.4  79.4  33.2  0.122  ...
# 182   NaN        Paul George  Ind  SF   23  80  36.0  74.7  28.4  0.125  ...
# 200   NaN      Blake Griffin  Lac  PF   24  80  35.6  73.9  29.1  0.119  ...
# 207   NaN       James Harden  Hou  SG   24  73  37.9  78.2  27.9  0.150  ...
# ...

# %%
empty_list_allstar13 = []
for i in player_stats_1213["PLAYER"]:
    if i in list(allstar_1213_concat["Player"]):
        empty_list_allstar13.append(1)
    else:
        empty_list_allstar13.append(0)
        
player_stats_1213["Allstar"] = empty_list_allstar13

player_stats_1213[player_stats_1213["Allstar"] == 1]
# Out:
#      Rank             PLAYER TEAM POS  AGE  GP   MPG  MIN%  USG%    TOr  ...  \
# 36    NaN      Blake Griffin  Lac  PF   23  80  32.3  67.1  25.5  0.128  ...
# 47    NaN        Brook Lopez  Bro   C   24  74  30.2  62.4  28.8  0.094  ...
# 54    NaN    Carmelo Anthony  Nyk  SF   28  67  36.9  76.5  35.8  0.093  ...
# 63    NaN         Chris Bosh  Mia   C   28  74  33.0  67.9  22.9  0.110  ...
# 69    NaN         Chris Paul  Lac  PG   27  70  33.2  68.9  22.8  0.137  ...
# 94    NaN          David Lee  Gol  PF   29  79  36.3  75.1  23.6  0.137  ...
# 122   NaN      Dwight Howard  Lal   C   27  76  35.6  73.8  22.3  0.166  ...
# 123   NaN        Dwyane Wade  Mia  SG   31  69  34.4  70.9  29.6  0.132  ...
# 180   NaN       James Harden  Hou  SG   23  78  38.1  78.9  29.2  0.149  ...
# 209   NaN        Joakim Noah  Chi   C   27  66  36.3  74.9  17.4  0.193  ...
# 230   NaN       Jrue Holiday  Phi  PG   22  81  36.9  76.6  26.5  0.173  ...
# ...

# %%
empty_list_allstar12 = []
for i in player_stats_1112["PLAYER"]:
    if i in list(allstar_1112_concat["Player"]):
        empty_list_allstar12.append(1)
    else:
        empty_list_allstar12.append(0)
        
player_stats_1112["Allstar"] = empty_list_allstar12

player_stats_1112[player_stats_1112["Allstar"] == 1]
# Out:
#      Rank             PLAYER TEAM POS  AGE  GP   MPG  MIN%  USG%    TOr  ...  \
# 12    NaN     Andre Iguodala  Phi  SG   28  62  35.4  73.5  17.7  0.137  ...
# 16    NaN       Andrew Bynum  Lal   C   24  60  35.0  71.8  23.9  0.139  ...
# 35    NaN      Blake Griffin  Lac  PF   22  66  36.1  74.5  26.7  0.109  ...
# 51    NaN    Carmelo Anthony  Nyk  SF   27  55  33.9  70.2  32.0  0.108  ...
# 61    NaN         Chris Bosh  Mia  PF   27  57  35.0  71.9  24.3  0.112  ...
# 64    NaN         Chris Paul  Lac  PG   26  60  36.2  74.7  24.4  0.108  ...
# 96    NaN     Deron Williams  Njn  PG   27  55  36.1  74.9  30.3  0.167  ...
# 99    NaN       Derrick Rose  Chi  PG   23  39  35.1  72.3  30.6  0.129  ...
# 105   NaN      Dirk Nowitzki  Dal  PF   33  62  33.3  68.4  29.4  0.089  ...
# 111   NaN      Dwight Howard  Orl   C   26  54  38.1  78.6  26.3  0.152  ...
# 112   NaN        Dwyane Wade  Mia  SG   30  49  33.0  67.5  31.5  0.118  ...
# ...

# %%
empty_list_allstar11 = []
for i in player_stats_1011["PLAYER"]:
    if i in list(allstar_1011_concat["Player"]):
        empty_list_allstar11.append(1)
    else:
        empty_list_allstar11.append(0)
        
player_stats_1011["Allstar"] = empty_list_allstar11

player_stats_1011[player_stats_1011["Allstar"] == 1]
# Out:
#      Rank             PLAYER TEAM POS  AGE  GP   MPG  MIN%  USG%    TOr  ...  \
# 17    NaN         Al Horford  Atl   C   24  77  34.9  72.6  19.8  0.106  ...
# 43    NaN      Blake Griffin  Lac  PF   21  82  37.8  78.0  27.4  0.117  ...
# 56    NaN    Carmelo Anthony  Den  SF   26  50  35.3  73.3  32.7  0.110  ...
# 57    NaN    Carmelo Anthony  Nyk  SF   26  27  36.0  73.9  31.2  0.094  ...
# 63    NaN         Chris Bosh  Mia  PF   26  77  36.1  74.8  23.6  0.098  ...
# 82    NaN         Chris Paul  Nor  PG   25  80  35.6  73.6  21.3  0.139  ...
# 112   NaN      Dwight Howard  Orl   C   25  78  37.4  77.4  27.4  0.162  ...
# 119   NaN      Dirk Nowitzki  Dal  PF   32  73  34.1  71.0  28.4  0.091  ...
# 120   NaN       Derrick Rose  Chi  PG   22  81  37.1  76.8  32.4  0.131  ...
# 122   NaN        Dwyane Wade  Mia  SG   29  76  37.0  76.6  31.8  0.124  ...
# 127   NaN     Deron Williams  Njn  PG   26  12  37.8  70.8  24.3  0.181  ...
# ...

# %%
empty_list_allstar10 = []
for i in player_stats_0910["PLAYER"]:
    if i in list(allstar_0910_concat["Player"]):
        empty_list_allstar10.append(1)
    else:
        empty_list_allstar10.append(0)
        
player_stats_0910["Allstar"] = empty_list_allstar10

player_stats_0910[player_stats_0910["Allstar"] == 1]
# Out:
#      Rank            PLAYER TEAM TRADE POS  AGE  GP  GM  GS   ORTG  ...  \
# 12    NaN        Al Horford  Atl   NaN   C   23  81   1  81  121.2  ...
# 14    NaN     Allen Iverson  Phi     √  SG   34  25  57  24  102.9  ...
# 47    NaN       Brandon Roy  Por   NaN  SG   25  65  17  65  117.7  ...
# 55    NaN   Carmelo Anthony  Den   NaN  SF   25  69  13  69  110.0  ...
# 59    NaN  Chauncey Billups  Den   NaN  PG   33  73   9  73  119.9  ...
# 61    NaN        Chris Bosh  Tor   NaN  PF   25  70  12  70  117.6  ...
# 72    NaN       Chris Kaman  Lac   NaN   C   27  76   6  76   99.2  ...
# 79    NaN        Chris Paul  Nor   NaN  PG   24  45  37  45  122.2  ...
# 109   NaN     Dwight Howard  Orl   NaN   C   24  82   0  82  113.7  ...
# 112   NaN         David Lee  Nyk   NaN  PF   26  81   1  81  116.2  ...
# 114   NaN     Dirk Nowitzki  Dal   NaN  PF   31  81   1  80  116.1  ...
# 115   NaN      Derrick Rose  Chi   NaN  PG   21  78   4  78  106.8  ...
# ...

# %%
allstar_0809_concat_last_names = []
for name in list(allstar_0809_concat["Player"]):
    allstar_0809_concat_last_names.append(name.split()[-1])
print(allstar_0809_concat_last_names)
# Out:
# ['Billups', 'Bryant', 'Duncan', 'Gasol', 'Ming', 'Nowitzki', "O'Neal", 'Parker', 'Paul', 'Roy', 'Stoudemire', 'West', 'Allen', 'Bosh', 'Garnett', 'Granger', 'Harris', 'Howard', 'Iverson', 'James', 'Johnson', 'Lewis', 'Nelson', 'Pierce', 'Wade', 'Williams']

# %%
empty_list_allstar09 = []
for i in revised_player_names:
    if i in allstar_0809_concat_last_names:
        empty_list_allstar09.append(1)
    else:
        empty_list_allstar09.append(0)
        
player_stats_0809["Allstar"] = empty_list_allstar09

player_stats_0809[player_stats_0809["Allstar"] == 1]
# Out:
#      Rank      Player  Age Team Pos  GP  GM   Usg    FG%    FT%  ...   Min  \
# 13    NaN     Iverson   33  Det  SG  54  28  26.8  0.416  0.786  ...  35.5
# 16    NaN     Johnson   21  Det  PF  62  20  11.6  0.595  0.657  ...  14.1
# 17    NaN     Johnson   34  Orl  PG  80   2  15.8  0.404  0.753  ...  18.3
# 25    NaN      Parker   33  Tor  SG  80   2  16.7  0.426  0.834  ...  32.3
# 27    NaN  Stoudemire   26  Pho  PF  53  29  24.3  0.539  0.835  ...  36.6
# 45    NaN         Roy   24  Por  SG  78   4  27.8  0.480  0.824  ...  37.0
# 57    NaN     Billups   32  Den  PG  76   6  22.0  0.420  0.912  ...  35.1
# 59    NaN        Bosh   24  Tor  PF  77   5  27.6  0.487  0.817  ...  37.3
# 70    NaN        Paul   23  Nor  PG  78   4  27.9  0.503  0.868  ...  38.3
# 91    NaN     Granger   25  Ind  SG  67  15  29.8  0.447  0.878  ...  36.0
# 93    NaN      Harris   25  Njn  PG  69  13  28.8  0.438  0.820  ...  36.0
# ...

# %% [markdown]
# ## Buraya Kadar

# %% [markdown]
# mali downloads season data from basketball refereance and adds all star column manually

# %% [markdown]
# data up to 2005 will be collected -> will be divided into training and test data

# %%
instagram_followers = pd.read_html('https://www.popularbasketballers.com')

instagram_followers = instagram_followers[0]

instagram_followers = instagram_followers.set_index("Rank")

instagram_followers
# Out:
#                        Name  Instagram Followers
# Rank
# 1              LeBron James            146120866
# 2             Stephen Curry             49330555
# 3         Russell Westbrook             21669462
# 4              Kyrie Irving             18539449
# 5                Lonzo Ball             16169099
# ...                     ...                  ...
# 446       Julian Champagnie                11620
# 447        Arnoldas Kulboka                10952
# 448            Terry Taylor                 8993
# 449   Javon Freeman-Liberty                 7630
# 450          Jordan Schakel                 5085
#
# [450 rows x 2 columns]

# %%
team_popularity = pd.read_html('http://www.espn.com/nba/attendance/_/sort/allPct')

team_popularity[0].head()

#instagram_followers = instagram_followers[0]

#instagram_followers = instagram_followers.set_index("Rank")

#instagram_followers
# Out:
#                 0                1     2       3      4      5     6      7   \
# 0  2023 Attendance  2023 Attendance  Home    Home   Home   Home  Road   Road
# 1               RK             TEAM   GMS   TOTAL    AVG    PCT   GMS    AVG
# 2                1         Warriors    31  559984  18064  100.0    30  20278
# 3                2        Mavericks    31  624663  20150  105.0    31  18022
# 4                3          Celtics    31  574680  19156  100.0    30  18812
#
#       8        9        10       11
# 0   Road  Overall  Overall  Overall
# 1    PCT      GMS      AVG      PCT
# 2  107.6       61    19134    103.7
# 3   96.4       62    19086    100.7
# 4   99.2       61    18984     99.6

# %%
social_media_followers = pd.read_html('https://www.wsn.com/nba/most-least-popular-nba-teams-social-media/')

social_media_followers
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 social_media_followers = pd.read_html('https://www.wsn.com/nba/most-least-popular-nba-teams-social-media/')
#       3 social_media_followers
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# we'll add each observation as a new row and add a column corresponding to the season / year
